# %% [markdown]
# # <center> Experiment manual:<br> How to combine the STM and the X-ray source in order to study properties of a single nanowire device</center>
#
#     Jovana Colvin
#     Division of Synchrotron Radiation Research
#     Lund University, Sweden

# %%
from IPython.display import Image
from IPython.core.display import HTML

import glob
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %% [markdown]
# <font color="red"> README.md explaining how to run the notebook added</font>
#
# # project-work-2018-joviwan
# list of dependances:
# <i>glob, numpy, pandas, matplotlib</i>
#
# To run the notebook, you need to install Anaconda, clone this directory, install and run the environment in the right directory with these commands in a terminal :
#
# - conda env create -f environment.yml
# - conda activate xray_stm

# %% [markdown]
# ## The aim of the manual and the scientific background
#
# Semiconductor nanowires (NW) are highly promising candidates for the next generation of opto-electronic devices <a href="#footnote-1">[1]</a> mainly due to its ability to accommodate the strain developed during the heteroepitaxial growth. In order to understand and improve the entire device performance it is crucial to study the individual nanowire. Being that device operation might influence the structural properties(e.g.,heating, piezotronic/piezophototronic effect), both <i>ex situ</i> and <i>in situ</i> experiments are needed to further explore the influence of the strain and defects distribution on the (opto)electrical properties of the nanowires.
#
# X-ray diffraction is suitable for experiments in operando. With recent advances, X-ray diffraction techniques, such as coherent Bragg diffraction imaging (CBDI), now provide information about the strain and defects distribution within individual nanostructures  <a href="#footnote-2">[2]</a>. At the ESRF (beamline ID13) with the beam energy of 14.8 keV and a focused nano-beam of 200X200nm it has been shown that it is possible to map phases in a single nanowire. The NW of interest is identified and by fulfilling the Bragg condition for reflection, different structural phases a single NW were found. Setting the incoming X-ray beam angle to one of phases and scanning along the NW growth axis, it was possible to encode the axial phase structure of the single NW.
#
# On the other hand, scanning tunneling microscopy (STM) can be used to measure the electrical properties of individual nanowires on their own growth substrate <a href="#footnote-3">[3]</a>. Bellow are the steps for performing the measurements combings the two techniques both ex situ and in situ. The STM part of the experiment provided the insight into I-V characteristics of the NW and was performed before and after the X-ray experiment, providing the possibility to study the impact of x-ray radiation on the NW properties
#
# The aim of this manual to help users how are trying to design the combined x-ray/STM experiments. In situ electrical measurements are performed in combination with X-ray diffraction by mounting a specifically designed STM onto the goniometer of a nanofocus beamline (BL). Here, the concept of the experiment is presented, aiming at the in situ characterization of Joule heating, piezoelectric response, or local strain induced by the nanoprobe, together with some initial results obtained on individual GaN nanowires.
# The manual assumes user's familiarity with both, STM and x-ray imaging techniques. It is to be used as a guidance tools with the aim of making the BL time more efficient as the problems encountered are identified and possible ways around provided.
#
# --------
#
#
# <p id="footnote-1">[1] Wallentin, Jesper, et al. "InP nanowire array solar cells achieving 13.8% efficiency by exceeding the ray optics limit." <i>Science</i> (2013): 1230969.
# </p>
#
# <p id="footnote-2">[2] Favre-Nicolin, V., et al. "Analysis of strain and stacking faults in single nanowires using Bragg coherent diffraction imaging." <i>New Journal of Physics</i> 12.3 (2010): 035013.
# </p>
#
# <p id="footnote-2">[2]Timm, Rainer, et al. "Current–voltage characterization of individual as-grown nanowires using a scanning tunneling microscope." <a>Nano letters</> 13.11 (2013): 5182-5189.
# </p>

# %% [markdown]
# ## The tools required for the experiment

# %%
df = pd.read_table('data/po8.txt',header=None,sep=',', names=[''])
df
# Out:
#
# Experimental station                  PETRA III: P08
# Method/Instrument      Kohzu 6-circle diffractometer
# Photon Energy                                   9KeV
# Beam Spot                                        2um
# Filling Mode                                     any
# EIGER X 1M                                       Yes
# MYTHEN                                           Yes
# CRL                                              Yes
# Optical microscope                               Yes
# PILATUS 300K                                     Yes
# SFM operating in air                             Yes

# %% [markdown]
# ## The beamline setup

# %% [markdown]
# 1. STM operating in air.
#  - Two probe materials available: W (sharp) and PtIr (rather dull)
#  - The sample is GaN/AlGaN nanowire grown on Si template.
#  - Bragg reflection for GaN at 9KeV:
#   - GaN [0001] om 7.6444
#   - GaN [0002] om 15.43
#   - GaN [0003] om 23.52
#
#
# 2. A goniometer stage is a device used to rotate object about a fixed point in space. It is used for aligning the x-ray beam to the STM tip apex while the fluorescence detector is monitoring the absorption peak of the STM tip.
#
#
# 3. Detector
# Pilatus 100k, Dectris
#
#
# 4. Focusing optics
# Focal length: 1.80 m to KOHZU diffractometer
#
#
# 5. X-ray parameters:
#  - at 9 KeV the x-ray beam size is aligned to 480nm (V) X 1.5um (H), the beam footprint (th=30) 960nm (V) X 1.5(um)

# %% [markdown]
# <figure>
#   <img src="images/setup.png" alt="" width="692">
#   <figcaption> Fig. 1 - The image (left) shows the setup at the PO8 with the main components labeled. The image to the right shows the STM (mounted on the goniometer stage) setup. </a></figcaption>
# </figure>
# <font color="red">figure width changed to 89 and 183mm</font>

# %% [markdown]
# ### Step 1. Aligning the STM proble to the NW of intrest

# %% [markdown]
# <strong>STM Imaging</strong>
#
# For sample imaging the STM is operated in constant current mode. The tip is approached to the sample until the tunneling current is measured. Once the condition for imaging is satisfied (tunneling current) the tip is first retracted by 2um (total nw length) and then approached in steps of 20 nm until the tip and the top part of the NW are close enough to trigger the interaction for the feedback resulting in the Fig.2 a).
#
# <strong>Contacting a single NW with the STM tip</strong>
#
# Once the NW of interest is identified, the tip is moved over the NW center (or until the largest z-piezo voltage is measured). Afterwards, the feedback is interrupted (see b)) and the current signal is provided with an external low noise current amplifier. External bias source is used to ramp the voltage (V) while measuring the current (I) such that I-V can be obtained over a specific NW. The contact is controlled with the tip z movement.

# %% [markdown]
# <figure>
#   <img src="images/stm_setup.png" alt="" width="692">
#   <figcaption> Fig. 2 - A method for utilizing the STM tip for both, imaging (top, schematics (left) and the acquired image of the NWs (right)) and contacting (bottom, schematics (left) and the plotted I-V curve (right)) of a single nanowire. </figcaption>
# </figure>

# %% [markdown]
# <strong>Note 1:</strong>
# The most efficient way to find the NW of interest is to either have a very good optical camera or fabricate markers on the samples large enough to be visible with the optical microscope.
#
# <figure>
#   <img src="images/1.png" alt="The figure shows Ti markers on the sample" width="337">
#   <figcaption> Fig. 3 - Three Ti markers deposited over the GaN substrate. </a></figcaption>
# </figure>

# %% [markdown]
# <strong>Note 2:</strong>
# Unfortunately the W tip cannot be used during in-situ without the additional source of nitrogen gas where one would enclose the setup in nitrogen environment. This is because the W tip oxidizes heavily during the exposure to the x-rays rendering imaging/contacting impossible. Hence, expensive and not as sharp PtIr probes are required. In addition, the best practice is to carry a standard sample for the tip characterization and mount it close to the sample of interest, making the time more efficient.
#
#
# <strong>STM Imaging</strong>
#
# The STM probe is best aligned to Ti marker.

# %% [markdown]
# ### Step 2. Position the goniometer to the Bragg angle

# %% [markdown]
# ### Step 3. Aligning the x-ray probe to the STM tip apex
#
# <strong>Rough alignment</strong>
#
# First, detector installed at 0deg was utilized for direct beam monitoring, where the STM system and the probe are visible and the rough alignment of the x-ray beam onto the STM probe is possible.  <figure>
#   <img src="images/db.png" alt="Macaque in the trees" width="337">
#   <figcaption> Fig. 4 - Aligning the x-ray beam onto the STM probe apex using the direct beam</a></figcaption>
# </figure>
#
# <strong>Fine alignment</strong>
#
# Absorption map from Pt (for the tip) and Ti (for the marker) diffraction peaks are recorded in order to allign the probe on the sample. For this the fluorescence detector is used resulting in the image shown in Fig 5.
#
# <figure>
#   <img src="images/3.png" alt="" width="337">
#   <figcaption> Fig. 5 - Fluorescence map showing the tip (left) and the marker on the sample (right) indicating correct alignment of the beam to the STM tip.</a></figcaption>
# </figure>

# %% [markdown]
# <strong>Note 3:</strong>
# It is recommended to use the goniometer with a smaller step size, large drifts in parallel (xs) and perpendicular (ys) directions to the beam were observed! The step size of the goniometer is 1um. Alternative is to move the STM stage in stead, and keep the goniometer fixed, safe for the rotation to Bragg angle.
#
#
# Finally the beam is scanned in xs and ys direction using the STM stage and the image in Fig. 5 is recorded.
#
# <figure>
#   <img src="images/2.png" alt="Macaque in the trees" width="337">
#   <figcaption> Fig. 5 - Fluorescence signal for Ti at roughly the expected position Three peaks are observed in xs direction separated by a distance of around 100um.</a></figcaption>
# </figure>

# %% [markdown]
# <strong>Note 4:</strong>
# It is possible to monitor the Ti signal on the STM photocurrent channel! See Fig. 6 for demonstration.
#
# <figure>
#   <img src="images/5.png" alt="Macaque in the trees" width="337">
#   <figcaption> Fig. 6 - Simultaneous monitoring the fluorescence signal for Ti and the x-ray induced photo current on the STM tip. .</a></figcaption>
# </figure>

# %% [markdown]
# <strong>Note 5:</strong>
# In addition, when using the GaN/AlGaN samples the x-ray beam location is visible by optical camera.  Hence, it is possible to, by changing the attenuation of the signal, monitor the beam location.

# %% [markdown]
# ### Step 4.  Check for diffraction pattern of NWs
# <figure>
#   <img src="images/k-map.png" alt="Macaque in the trees" width="337">
#   <figcaption> Fig. 7 - k-map displaying diffraction pattern of nanowires indicating more then a few NWs.</a></figcaption>
# </figure>

# %% [markdown]
# ### Step 5.  Identify a single nanowire and start the experiment
#
#
# Fig. 8 shows an evolution of the diffraction pattern with different tip sample loading forces. Left image is recorder at the initial tip-NW contact, middle with some induced strain, and right with the force enough to break the nanowire. Since the beam is rather large, it is not possible to escape illuminating several NWs at the time, hence not observing the effect on the single NW level.
# <figure>
#   <img src="images/cQcngr.png" alt="Macaque in the trees" width="692">
#   <figcaption> Fig. 8 - Diffraction patern of nanowires indicating more then a few NWs.</a></figcaption>
# </figure>

# %% [markdown]
# Different I-V spectra are recorded: a) at different attenuation levels (10e2, 10e3, 10e4) and different tip loading forces. The resulting data is plotted in the figure bellow.

# %%
filelist=[]

for i in range(2,5):
    filelist.append("./data/ct10e%d.txt" %i)

for filename in filelist:
    data=np.loadtxt(filename)
    voltage=data[:,1]
    current=data[:,0]
    plt.plot(voltage,current*1e9, label= filename);
    plt.legend(loc='best')    
    
    fig_size = plt.rcParams["figure.figsize"]
    fig_size[0] = 12
    fig_size[1] = 9
    plt.rcParams["figure.figsize"] = fig_size 
    
    plt.ylabel('current [nA]')
    plt.xlabel('voltage [V]')
    plt.title('Current-Voltage') 
    fig_size[0] = 12
    fig_size[1] = 9
    plt.rcParams["figure.figsize"] = fig_size
    
    plt.rcParams.update({'font.size': 12,
                     'xtick.major.width': 1.0, 
                     'ytick.major.width': 1.0, 
                     'axes.labelsize': 12, 
                     'axes.linewidth': 1.0, 
                     'axes.labelpad': 2,
                     'xtick.labelsize': 12, 
                     'ytick.labelsize': 12,  
                     'xtick.major.size': 8, 
                     'ytick.major.size': 8 ,
                     'legend.fontsize': 10})
plt.savefig(r'data_plotted/' + 'applied_load' + r'.png', facecolor='w', edgecolor='w', orientation='portrait', papertype=None, format=None, transparent=True, bbox_inches=None, pad_inches=0.1, frameon=None, dpi=300)

# %% [markdown]
# <font color="red">Using matplotlib to save data instead of pandas</font>
#
# <font color="red">perform data operations using numpy, scipy, pandas or equivalent- no</font>

# %%
images = []
for img_path in glob.glob('data_plotted/*.png'):
    images.append(mpimg.imread(img_path))

plt.figure(figsize=(70, 70))
columns = 2

for i, image in enumerate(images):
    plt.subplot(len(images) / columns + 1, columns, i + 1)
    plt.imshow(image)
    plt.axis("off")

# %% [markdown]
# ## Solution to the problems accountered

# %% [markdown]
# 1. The photoejected electrons from the sample are interfering with the measurements of tunneling current, thus it is necessary to reduce the intensity of the beam by changing the attenuation. It is highly advised to be able to change the attenuation remotely in order to prevent the entrance the the hutch and thus switching the beam on and off contantly.
#
#
# 2. STM instabilities are best explained by the stage tilt drift due to the large angle (23ged) required for Bragg reflection. If it is not possible to used a higher energy beam where the Bragg reflection is smaller perhaps moving to GaN [0001] Bragg angle is sufficient.
#
# 3. The tip must be stable, firmly glued to the tip stage! The best practice is to mount several probes in advance allowing the conductive glue to harden.

# %% [markdown]
# # Conclusion
#
# After the beamtime at the BL PO8 we have developed a "quick" method for combining the x-ray and STM techniques. Although very challenging, the experiment is believed possible at the beamline that offers a smaller beam size. Challenges that have not been anticipated are now successfully solved.
